# %% [markdown]
# # **1. Jupyter Notebook**

# %% [markdown]
# ### 1. 모드(mode)
# * 일반 모드(Command mode): 셀을 선택하고 이동하거나, 셀을 추가, 삭제 등의 작업을 수행(Enter)
# * 편집 모드(Edit mode): 셀의 내용을 편집하거나 코드를 작성할 수 있음(Esc)

# %% [markdown]
# ### 2. 일반 모드 단축키
# * A: 셀 위에 새로운 셀 추가
# * B: 셀 아래 새로운 셀 추가
# * D, D: 선택된 셀 삭제
# * Y: 선택된 셀을 코드 셀로 변경
# * M: 선택된 셀을 마크다운 셀로 변경
# * Z: 셀 삭제를 취소

# %% [markdown]
# ### 3. 편집 모드 단축키
# * 컨트롤 + Z: 되돌리기
# * 컨트롤 + Y: 되돌리기 취소
# * 컨트롤 + A: 셀 내용 전체 선택
# * 컨트롤 + X: 선택한 내용 잘라내기
# * 컨트롤 + C: 선택한 내용 복사하기
# * 컨트롤 + V: 선택한 내용 붙여넣기
# * 컨트롤 + Home: 셀 맨 위로 이동
# * 컨트롤 + End: 셀 맨 아래로 이동
# * 컨트롤 + D: 현재 줄 삭제
# * 쉬프트 + 탭: 도움말 툴팁 표시
# * 탭: 자동 완성 기능

# %% [markdown]
# # **2. 셀레니움**
# Selenium은 웹 애플리케이션을 자동화하기 위한 오픈 소스 툴로, 브라우저를 프로그래밍적으로 제어하여 사람처럼 웹을 탐색하거나 상호작용할 수 있게 합니다. 주로 웹 테스트 자동화와 크롤링에 사용되며, 동적인 콘텐츠나 자바스크립트 렌더링이 필요한 웹 페이지에서도 효과적으로 동작합니다. Selenium WebDriver를 사용하면 Python, Java, C# 등 다양한 프로그래밍 언어로 브라우저를 제어할 수 있으며, Chrome, Firefox, Edge 등 여러 브라우저에서 작업이 가능합니다. 이를 통해 로그인, 폼 제출, 버튼 클릭, 데이터 스크랩과 같은 작업을 자동화할 수 있습니다.

# %%
# !pip install selenium
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/9.7 MB 9.8 MB/s eta 0:00:01
#    ------ --------------------------------- 1.5/9.7 MB 15.7 MB/s eta 0:00:01
#    ------------ --------------------------- 3.0/9.7 MB 21.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.7 MB 27.6 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.7 MB 35.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 38.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 34.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/481.7 kB ? eta -:--:--
#    --------------------------------------- 481.7/481.7 kB 29.5 MB/s eta 0:00:00
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()
driver.get('https://www.google.com')

# %%
search = driver.find_element('name', 'q')
search.send_keys('크리스마스')
search.send_keys(Keys.RETURN)

# %%
driver = webdriver.Chrome()
driver.get('https://www.google.com')
search = driver.find_element('name', 'q')
search.send_keys('크리스마스')
search.send_keys(Keys.RETURN)

# %%
# !pip install bs4
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()
driver.get('https://www.google.com')
html = driver.page_source
soup = BeautifulSoup(html)
search = soup.select('#APjFqb')
search.send_keys('')

# %% [markdown]
# # **3. 네이버 웹툰 크롤링**
# * [조조코믹스](https://comic.naver.com/webtoon/detail?titleId=774862&no=165&week=wed)

# %%
import time

# %%
driver = webdriver.Chrome()
driver.get('https://comic.naver.com/webtoon/detail?titleId=774862&no=165&week=wed')
time.sleep(2)
soup = BeautifulSoup(driver.page_source)
comment_area = soup.find_all('span', {'class':'u_cbox_contents'})
print('**********베스트 댓글**********')
for i in range(len(comment_area)):
    comment = comment_area[i].text.strip()
    print(comment)
# Out:
# **********베스트 댓글**********
# 됐다.... 해산.
# 하이는 확신같은게 필요했나바.. 애나가 애매하게 안하고 딱 잘라 말하니까 바로 갈기네 ㅠㅠ
# 아니 근데 니네 언제 고백했니
# 진짜 애나가 다하네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 이동건 : 옛다 키스
# 미친다미친다 이거 배경화면배포해 당장
# 감찰부 너 승진
# 솔직히 4년 짝사랑이니까 좀 더 조심스러웠을 거 같애 미쳤다 ㅠㅠ
# 애나만 사귀는 줄 걱정했잖아
# 내가 이거보려고 여기까지 달려왔다
# 4년 짝사랑 이루어진 것 도 그렇고 사귄지 첫날부터 한 침대 옆에서 누워있음 ㄷㄷ 이런데 잠이 대수냐고
# 단 한페이지에 바뀌는 민심 ㅋㅋㅋ
# 언니 개멋지다 정말 😍
# 샤즈인지 샤브인지 말고 너거 사귀는 얘기나 해
# 나도 이제야 실감이 나..

# %%
driver.find_element('xpath','/html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/div/div[4]/div[1]/div/ul/li[2]/a/span[2]').click()

# %%
time.sleep(2)
soup = BeautifulSoup(driver.page_source)
comment_area = soup.find_all('span', {'class':'u_cbox_contents'})
print('**********전체 댓글**********')
for i in range(len(comment_area)):
    comment = comment_area[i].text.strip()
    print(comment)
# Out:
# **********전체 댓글**********
# 와씨~~!!!!!
# 거뷱목
# 애나 팔 언제 내렸어
# 애나 하이 입술만 보고 있는 거 넘 티난다
# 다음주부터 19세로 만나뵙겠습니다
# 좋습니다 작가님, 계속 이렇게만 합시다 작가님
# 이동건 작가님의 저런 (대통령 파자마와 같은) 귀여운 디테일들 너무 좋아용 ㅋㅋ
# ≖‿≖
# 실감이 납니다ㅏㅏㅏㅏㅏ
# 짐깐 설마 뒤돈거 설마 그거
# 휴
# 아니 정말 미친자인가?? 이거 찌질의 역사임????
# 고작 입뭊춤에 이렇게 설렐일인가요???? 꺄~~~~~
# 야ㅏㅏㅏㅏㅏㅏㅏㅏㅜ갸ㅏㅏㅏㅏㅏㅏ아아아ㅏ가가가아아야아아아아야아앙

# %%
driver = webdriver.Chrome()
driver.get('https://comic.naver.com/webtoon/detail?titleId=774862&no=165&week=wed')
time.sleep(2)
soup = BeautifulSoup(driver.page_source)
comment_area = soup.find_all('span', {'class':'u_cbox_contents'})
print('**********베스트 댓글**********')
for i in range(len(comment_area)):
    comment = comment_area[i].text.strip()
    print(comment)
driver.find_element('xpath','/html/body/div[1]/div[5]/div/div/div[5]/div[1]/div[3]/div/div/div[4]/div[1]/div/ul/li[2]/a/span[2]').click()
time.sleep(2)
soup = BeautifulSoup(driver.page_source)
comment_area = soup.find_all('span', {'class':'u_cbox_contents'})
print('**********전체 댓글**********')
for i in range(len(comment_area)):
    comment = comment_area[i].text.strip()
    print(comment)
# Out:
# **********베스트 댓글**********
# 됐다.... 해산.
# 하이는 확신같은게 필요했나바.. 애나가 애매하게 안하고 딱 잘라 말하니까 바로 갈기네 ㅠㅠ
# 아니 근데 니네 언제 고백했니
# 진짜 애나가 다하네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 이동건 : 옛다 키스
# 미친다미친다 이거 배경화면배포해 당장
# 감찰부 너 승진
# 솔직히 4년 짝사랑이니까 좀 더 조심스러웠을 거 같애 미쳤다 ㅠㅠ
# 애나만 사귀는 줄 걱정했잖아
# 내가 이거보려고 여기까지 달려왔다
# 4년 짝사랑 이루어진 것 도 그렇고 사귄지 첫날부터 한 침대 옆에서 누워있음 ㄷㄷ 이런데 잠이 대수냐고
# 단 한페이지에 바뀌는 민심 ㅋㅋㅋ
# 언니 개멋지다 정말 😍
# 샤즈인지 샤브인지 말고 너거 사귀는 얘기나 해
# 나도 이제야 실감이 나..
# **********전체 댓글**********
# 잉이ㅣㄱㄱ 미친
# 와씨~~!!!!!
# 거뷱목
# 애나 팔 언제 내렸어
# 애나 하이 입술만 보고 있는 거 넘 티난다
# 다음주부터 19세로 만나뵙겠습니다
# 좋습니다 작가님, 계속 이렇게만 합시다 작가님
# 이동건 작가님의 저런 (대통령 파자마와 같은) 귀여운 디테일들 너무 좋아용 ㅋㅋ
# ≖‿≖
# 실감이 납니다ㅏㅏㅏㅏㅏ
# 짐깐 설마 뒤돈거 설마 그거
# 휴
# 아니 정말 미친자인가?? 이거 찌질의 역사임????
# 고작 입뭊춤에 이렇게 설렐일인가요???? 꺄~~~~~

# %% [markdown]
# # **4. 야놀자 리뷰 크롤링**

# %%
def crawl_yanolja_reviews(name, url):
    review_list = []
    driver = webdriver.Chrome()
    driver.get(url)
    time.sleep(3)

    scroll_count = 3
    for i in range(scroll_count):
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)

    html = driver.page_source
    soup = BeautifulSoup(html)

    review_containers = soup.select('#__next > section > div > div.css-1js0bc8 > div > div > div')
    review_date = soup.select('#__next > section > div > div.css-1js0bc8 > div > div > div > div.css-1toaz2b > div > div.css-1ivchjf > p')
    # print(len(review_containers))
    # print(review_date)
    for i in range(len(review_containers)):
        review_text = review_containers[i].find('p', class_='content-text').text
        review_star = review_containers[i].find_all('path', {'fill':'#FDBD00'})
        # print(review_text)
        star_cnt = len(review_star)
        # print(star_cnt)
        date = review_date[i].text
        # print(date)
        # print('*****')
        review_dict = {
            'review' : review_text,
            'star' : star_cnt,
            'date' : date
        }
        review_list.append(review_dict)
    print(review_list)

# %%
crawl_yanolja_reviews(name='야놀자', url='https://www.yanolja.com/reviews/domestic/3013409')
# Out:
# [{'review': '경포대 바로 앞 위치하며 뒤편으로는 경포 호수와 바다를 사이에 둔 호텔이에요.\n휴가기간인 성수기 평일이나 주차, 체크인 등 전체적으로 수월하고 빠르게 여유롭게 지낼 수 있었어요.\n방안에 테이블, 와인잔/오프너 등 간단하게 준비되어 있고 생수 두 병이 있어 포장해서 먹거리를 먹어도 될 것 같습니다,\n욕실에 다회용 어매니티가 비치되어 있기는 하지만 칫솔, 치약, 면도기, 클렌징폼은 챙겨가셔야 합니다.\n없어도 자판기에서 상시 판매하며 호텔 내부에 편의점에 판매하고 있습니다.\n조식은 1층에서 7시부터 이용할 수 있고 규모가 크지는 않지만 한식메뉴가 적당하게 있다고 하니 따로 추기하여 이용하지 않았습니다.\n방에서 시야방해없이 넓게 바다를 볼 수 있는 점이 가장 큰 장점인 곳이며\n택시 버스정류장이 인근에 있어 댖 ㅇ교통으로 여행하기도 좋을 갓 같아요.\n숙소 내부 또한 인근에도 밥집이 많으나 가격대가 높습니다.\n만족스러운 요행 할 수 있었습니다.\n수영장 이용 시 수건 하나 제공이며 팔찌 끊어내지 않으면 재입장 가능하다고 합니다', 'star': 5, 'date': '2024.08.15'}, {'review': '실제 방문 후기 입니다 솔직하게 여자친구와 1주년 기념으로 이 호텔에 방문했고 리뷰들을 보면서 살짝 걱정을 많이 했었습니다 첫 날에 호텔에 도착했을때 직원분께서 차 문을 열어주시고 체크인 하는곳을 안내를 해주시는 모습에 많이 기분 좋았습니다 그리고 체크인 후 방 청결도 상태도 매우 좋아서 기분이 좋았고 하지만 바닥에 긁힌 자국들은 어쩔 수 없는걸 알기에 감안하여도 매우 좋았습니다 실내 슬리퍼가 없다는 리뷰를 보고 사야겠다 마음을 먹었는데 방 옷장에 구비되어 있는 슬리퍼가 있어서 소소하게 기분이 좋더라구요 제 불찰로 창문을 열어두고 외출을 해서 날파리들이 많이 방으로 들어왔는데 늦은 시각에도 에프킬라를 가져다 주시는 모습에 많이 감사했습니다 그리고 인피니티풀은 인당 3만원인데 만약 수영복을 챙기지 못하셨다면 호텔 cu에서 
# ...

# %% [markdown]
# # **5. 요기요 리뷰 크롤링**

# %%
import re # 정규표현식 처리를 위한 모듈
import time
from bs4 import BeautifulSoup
from selenium import webdriver
# NoSuchElementException: 찾으려는 요소가 없는 경우
# TimeoutException: 특정 시간이 지나도 조건이 충족되지 않을 때
# ElementNotInteractableException: 요소가 상호작용 불가능할 때
from selenium.common.exceptions import NoSuchElementException, TimeoutException, ElementNotInteractableException
from selenium.webdriver.common.by import By
# 특정 조건을 기다릴 때 사용
from selenium.webdriver.support import expected_conditions as EC
# 조건이 충족되 때까지 대기
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ### 5-1. 정규 표현식
# 정규 표현식(regular expression)은 문자열에서 특정 패턴을 찾거나 검증하거나 변경할 때 유용하게 사용되는 표현식

# %%
# r(raw string): 이스케이프 처리되지 않도록 만듦
# f: 문자열 안에 변수를 삽입하거나 표현식을 평가하여 문자열에 포함
email_pattern = r'^[a-zA-Z0-9.-]+@[a-zA-Z0-9.-]+\.[a-zA-Z]{2,}$'

user_input = input('이메일을 입력하세요: ')

if re.match(email_pattern, user_input):
    print('유효한 이메일 주소입니다.')
else:
    print('올바르지 않은 이메일 형식입니다')
# Out:
# 이메일을 입력하세요:  dffsdf@dfdfsd.dfdf
# 유효한 이메일 주소입니다.

# %% [markdown]
# ### 5-2. 전역 변수

# %%
BASE_URL = 'https://www.yogiyo.co.kr/mobile/#/'
URL = [
    'https://www.yogiyo.co.kr/mobile/#/237324/'
    #'https://www.yogiyo.co.kr/mobile/#/561367/'
    #'https://www.yogiyo.co.kr/mobile/#/1373032/'
    #'https://www.yogiyo.co.kr/mobile/#/255111/'
]

# %% [markdown]
# ### 5-3. 크롤링 함수

# %%
def crawl_single_restaurant(url):
    chrome_options = webdriver.ChromeOptions()
    prefs = {'profile.default_content_setting_values.geolocation': 2}
    chrome_options.add_experimental_option('prefs', prefs)

    driver = webdriver.Chrome(options=chrome_options)
    driver.get(BASE_URL)
    time.sleep(2)

    search_box = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="search"]/div/form/input'
    )))

    my_address = '명일동'
    search_box.send_keys(my_address)
    search_btn = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="button_search_address"]/button[2]')))
    search_btn.click()
    time.sleep(2)

    address1 = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="search"]/div/form/ul/li[3]/a')))
    address1.click()
    time.sleep(2)

    driver.get(url)
    time.sleep(5)

    clean_review_btn = driver.find_element(By.XPATH, '//*[@id="content"]/div[2]/div[1]/ul/li[2]/a/span')
    clean_review_btn.click()
    time.sleep(2)

    # for i in range(True):
    #     more_review_btn = WebDriverWait(driver, 10).until(
    #     EC.visibility_of_element_located((By.XPATH, '//*[@id="review"]/li[12]/a')))
    #     more_review_btn.click()
    #     driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    #     time.sleep(2)

    while True:
        try:
            more_review_btn = WebDriverWait(driver, 3).until(
                EC.element_to_be_clickable((By.XPATH, '//*[@id="review"]/li/a')))
            more_review_btn.click()
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            time.sleep(3)
        except(NoSuchElementException, TimeoutException, ElementNotInteractableException):
            break

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    restaurant_name = soup.select_one('#content > div.restaurant-detail.row.ng-scope > div.col-sm-8 > div.restaurant-info > div.restaurant-title > span').get_text(strip=True)
    # print(restaurant_name)
    reviews = soup.select('#review > li > p')
    review_texts = [review.get_text(strip=True) for review in reviews][1:]
    # print(review_texts)
    menus = soup.select('#review > li > div.order-items.ng-binding')
    all_menu = [menu.get_text(strip=True) for menu in menus]
    # print(all_menu)

    document = {
        "restaurant": restaurant_name,
        "url": url,
        "reviews": []
    }

    for menu, text in zip(all_menu, review_texts):
        document['reviews'].append({
            "menus": menu,
            "review_text": text
        })
    print(document)

# %%
crawl_single_restaurant('https://www.yogiyo.co.kr/mobile/#/1359631/')
# Out:
# {'restaurant': '자담치킨-상일점', 'url': 'https://www.yogiyo.co.kr/mobile/#/1359631/', 'reviews': [{'menus': '맵슐랭치킨/1(매운맛선택(마일드（순한맛）),음료 메뉴 변경(콜라))', 'review_text': '상일점 최고!!!\n주문하면 배달도 빠르고 맵슐랭 치킨 너무 맛있어서 자주 주문합니다^*^'}, {'menus': '간장치킨/1(음료 메뉴 변경(콜라))', 'review_text': '자담치킨 처음먹어봐요!!! 기대됩니다'}, {'menus': '맵슐랭치킨/1(매운맛선택(오리지날（매운맛）),음료 메뉴 변경(콜라))', 'review_text': '항상 맛있게 먹고있습니다 ㅎ 너무 맛있습니다'}, {'menus': '후라이드치킨/1(음료 메뉴 변경(콜라),소스추가(매운양념소스))', 'review_text': '후라이드가  바삭바삭 고소하고 맛있어요\n소스두가지 기본으로 주시는 센스♡'}, {'menus': '핫순살양념반반치킨/1(음료 메뉴 변경(콜라))', 'review_text': '닭의 퀄리티가 남달라요. 핫은 아이가 좀 맵다하여 담부터는 일반으로 주문해야 겠어요.'}, {'menus': '3반순살치킨세트/1(맛선택（3반순살）(맵슐랭(마일드반)),음료 메뉴 변경(콜라))', 'review_text': '배달도빠르고 맛있음'}, {'menus': '양념치킨/1(음료 메뉴 변경(콜라))', 'review_text': '여기 매장가서 먹어보고 완전반해서 배달도 시켰어요ㅎ\n브랜드치킨도 매장별다르던데 우리동네 상일점 자담은 진짜 최고맛있습니다.\n양념은 이제 자담으로 갈아탔어요.\n\n치즈볼도감사드립니당♡'}, {'menus': '왓더핫반반치킨/1(매운맛선택(마일드（순한맛）),음료 메뉴 변경(콜라)),양념순살치킨/1(음료 메뉴 변경(콜라))', 'review_text': '배달예상시간보다 빨리 왔고\n너무 맛있게 잘 먹었습니다~'}, {'menus': '양념반반치킨/1(음료 메뉴
# ...

# %%
import re # 정규표현식 처리를 위한 모듈
import time
from bs4 import BeautifulSoup
from selenium import webdriver
# NoSuchElementException: 찾으려는 요소가 없는 경우
# TimeoutException: 특정 시간이 지나도 조건이 충족되지 않을 때
# ElementNotInteractableException: 요소가 상호작용 불가능할 때
from selenium.common.exceptions import NoSuchElementException, TimeoutException, ElementNotInteractableException
from selenium.webdriver.common.by import By
# 특정 조건을 기다릴 때 사용
from selenium.webdriver.support import expected_conditions as EC
# 조건이 충족되 때까지 대기
from selenium.webdriver.support.ui import WebDriverWait
BASE_URL = 'https://www.instagram.com/'
URL = 'https://www.instagram.com/explore/search/keyword/?q=%23%EB%A8%B9%EB%B0%A9'

def likes_insta(url, like):
    chrome_options = webdriver.ChromeOptions()
    prefs = {'profile.default_content_setting_values.geolocation': 2}
    chrome_options.add_experimental_option('prefs', prefs)

    driver = webdriver.Chrome(options=chrome_options)
    driver.get(BASE_URL)
    time.sleep(3)

    user_id_box = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="loginForm"]/div/div[1]/div/label/input'
    )))
    user_id = 'jungbal429800@gmail.com'
    user_id_box.send_keys(user_id)
    time.sleep(2)

    user_pw_box = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="loginForm"]/div/div[2]/div/label/input'
    )))
    user_pw = 'jinlee1227!'
    user_pw_box.send_keys(user_pw)
    time.sleep(2)

    search_login_btn = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '//*[@id="loginForm"]/div/div[3]'
    )))
    search_login_btn.click()
    time.sleep(10)
    
    driver.get(f'https://www.instagram.com/explore/search/keyword/?q=%23{url}')
    time.sleep(5)

    select_image = WebDriverWait(driver, 10).until(
        EC.visibility_of_element_located((By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[2]/div/div[1]/div[2]/div/a/div/div[2]'
    )))
    select_image.click()
    time.sleep(3)

    soup = BeautifulSoup(driver.page_source)

    for i in range(like):
        try:
            if i == 0:
                like_buttons_xpath = '/html/body/div[6]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div'
            else: 
                like_buttons_xpath = '/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div'
            like_btn = WebDriverWait(driver, 10).until(
                EC.visibility_of_element_located((By.XPATH, like_buttons_xpath
        )))
            like_btn.click()
            time.sleep(5)
            
            next_buttons = driver.find_elements(By.CLASS_NAME, '_abl-')
            if len(next_buttons) <= 2:
                next_btn = next_buttons[0]
                next_btn.click()
            elif len(next_buttons) > 2:
                next_btn = next_buttons[1]
                next_btn.click()
            time.sleep(3)
        except (NoSuchElementException, TimeoutException, ElementNotInteractableException):
            print("error")
            time.sleep(2)
            continue

# %%
likes_insta('푸들', 7)
# Out:
# error
# error
# error
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 likes_insta('푸들', 7)
#
# Cell In[86], line 63, in likes_insta(url, like)
#      61     else:
#      62         like_buttons_xpath = '/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div'
# ---> 63     like_btn = WebDriverWait(driver, 10).until(
#      64         EC.visibility_of_element_located((By.XPATH, like_buttons_xpath
#      65 )))
#      66     like_btn.click()
#      67     time.sleep(5)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\support\wait.py:96, in WebDriverWait.until(self, method, message)
#      94 while True:
#      95     try:
# ---> 96         value = method(self._driver)
#      97         if value:
#      98             return value
#
# ...

# %%
/html/body/div[6]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[7]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[7]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[6]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
/html/body/div[5]/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[3]/div/div/section[1]/span[1]/div/div
