# %% [markdown]
# # **1. 조건문**
# 조건문은 코드의 실행 흐름을 제어하기 위해 사용하는 구문입니다. 이 조건문은 주어진 조건이 참인지 거짓인지에 따라 다른 코드를 실행하게 합니다.

# %% [markdown]
# # **2. if 문**
# 가장 기본적인 조건문입니다. 특정 조건이 참(True)일 경우에만 해당 블록 내의 코드가 실행됩니다.
#
# ```
# if 조건:
#     실행할 코드
# ```
#
# 여기에서 조건은 True 또는 False로 평가될 수 있는 표현식이어야 합니다. 조건이 True로 평가되면 if 문 바로 아래의 코드 블록이 실행됩니다. 그렇지 않으면 그 코드 블록은 건너뜁니다.

# %%
if True:
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 결과는 참입니다.
# 프로그램을 종료합니다.

# %%
if False:
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 프로그램을 종료합니다.

# %%
if '안녕하세요':
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 결과는 참입니다.
# 프로그램을 종료합니다.

# %%
if '':
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 프로그램을 종료합니다.

# %%
if '안녕하세요':print('결과는 참입니다')
print('프로그램을 종료합니다')
# Out:
# 결과는 참입니다
# 프로그램을 종료합니다

# %%
if '':print('결과는 참입니다')
print('프로그램을 종료합니다')
# Out:
# 프로그램을 종료합니다

# %%
if '안녕하세요':
  print('안녕하세요')
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 안녕하세요
# 결과는 참입니다.
# 프로그램을 종료합니다.

# %%
if '':
  print('안녕하세요')
  print('결과는 참입니다.')
print('프로그램을 종료합니다.')
# Out:
# 프로그램을 종료합니다.

# %%
age = int(input('나이를 입력하세요'))

if age > 19:
  print('성인입니다.')
  print('넷플릭스 성인 영화를 감상할 수 있습니다.')
print('입력한 나이: ', age)
# Out:
# 나이를 입력하세요15
# 입력한 나이:  15

# %% [markdown]
# # **3. esle 문**
# else 문은 조건문에서 특정 조건이 충족되지 않을 때 실행할 코드 블록을 정의할 때 사용합니다.
#
# ```
# if 조건1:
#     코드 블록1
# else:
#     코드 블록3
# ```

# %%
age = int(input('나이를 입력하세요'))

if age > 19:
    print('성인입니다')
    print('넷플릭스 성인영화를 감상할 수 있어요')
else:
    print('미성년입니다')
    print('디즈니플러스를 보세요')
print('입력한 나이: ', age)
# Out:
# 나이를 입력하세요20
# 성인입니다
# 넷플릭스 성인영화를 감상할 수 있어요
# 입력한 나이:  20

# %% [markdown]
# # **4. el if 문**
# elif는 if-else 구조에서 추가적인 조건을 검사하기 위해 사용합니다. elif는 "else if"의 줄임말이며, 주어진 여러 조건 중에서 하나만 참일 때 실행되는 코드 블록을 정의합니다.
#
# - elif는 if 없이 단독으로 사용될 수 없습니다.
#
# - elif는 필요에 따라 여러 번 사용될 수 있습니다.
#
# - else는 선택적입니다. 사용될 경우, 항상 if나 elif 뒤에 나타나야 합니다.
#
# ```
# if 조건1:
#     코드 블록1
# elif 조건2:
#     코드 블록2
# elif 조건3:
#     코드 블록3
# else:
#     코드 블록4
# ```

# %%
score = int(input('점수를 입력하세요'))

if score >= 90:
  print('A')
elif score >= 80:
  print('B')
elif score >= 70:
  print('C')
elif score >= 60:
  print('D')
else:
  print('F')
# Out:
# 점수를 입력하세요90
# A

# %%
age = int(input('나이를 입력하세요: '))

if age > 19:
  print('성인입니다')
elif age > 14:
  print('청소년입니다')
elif age > 6:
  print('어린이입니다')
elif age > 0:
  print('유아입니다')
else:
  print('입력을 확인해주세요')
print('입력한 나이:', age)
# Out:
# 나이를 입력하세요: 19
# 청소년입니다
# 입력한 나이: 19

# %% [markdown]
# ### 문제1
# * 로그인 프로그램 만들기
# * 예) 아이디: admin, 비밀번호: 1234

# %%
# 로그인 프로그램 만들기
# 아이디: admin, 비밀번호: 1234
userid = input('아이디를 입력하세요')
userpw = input('비밀번호를 입력하세요')

if userid == 'admin' and userpw == '1234':
    print('로그인 되었습니다')
else:
    print('아이디 또는 비밀번호를 확인하세요')
# Out:
# 아이디를 입력하세요admin
# 비밀번호를 입력하세요41111
# 아이디 또는 비밀번호를 확인하세요

# %% [markdown]
# ### 문제2
# * 주민등록번호에 의한 성별을 판별하는 프로그램 만들기
# * 예) 0010113068518

# %%
juminNo = input('주민등록번호 13자리를 -없이 입력하세요')

if juminNo[6] == '1' or juminNo[6] == '3' or juminNo[6] == '5' or juminNo[6] == '7' or juminNo[6] == '9':
    print('남자')
else:
    print('여자')
# Out:
# 주민등록번호 13자리를 -없이 입력하세요9909211083621
# 남자

# %%
juminNo = input('주민등록번호 13자리를 -없이 입력하세요')
if int(juminNo[6]) % 2 == 1:
    print('남자')
else:
    print('여자')
# Out:
# 주민등록번호 13자리를 -없이 입력하세요1234561111111
# 남자

# %%
while(True):
  juminNo = input('주민등록번호 13자리를 -없이 입력하세요')
  if len(juminNo) == 13:
    if int(juminNo[6]) % 2 == 1:
      print('남자')
    else:
      print('여자')
    break
  else:
    print('13자리를 입력해주세요')
# Out:
# 주민등록번호 13자리를 -없이 입력하세요1111121315464654654
# 13자리를 입력해주세요
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-3cd6cbe10f8c> in <cell line: 1>()
#       1 while(True):
# ----> 2   juminNo = input('주민등록번호 13자리를 -없이 입력하세요')
#       3   if len(juminNo) == 13:
#       4     if int(juminNo[6]) % 2 == 1:
#       5       print('남자')
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### 문제3
# * 간단한 MBTI 유형 검사를 만들어보자

# %%
print("MBTI 간단 성격 유형 검사에 오신 걸 환영합니다!")

# 첫 번째 질문: 외향/내향
answer1 = input("Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): ")
if answer1.lower() == 'y':
    # 외향형으로 진행
    print("외향형으로 분석 중...")
    answer2 = input("Q2. 주변 환경에 대해 자주 인지하고 있나요? (y/n): ")

    if answer2.lower() == 'y':
        # 감각형(외향, 감각)
        answer3 = input("Q3. 계획을 세우는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ESTJ입니다!")
        else:
            print("당신의 성격 유형은 ESFP입니다!")
    else:
        # 직관형(외향, 직관)
        answer3 = input("Q3. 큰 그림을 보는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ENFP입니다!")
        else:
            print("당신의 성격 유형은 ENTJ입니다!")

else:
    # 내향형으로 진행
    print("내향형으로 분석 중...")
    answer2 = input("Q2. 구체적인 정보나 사실을 중요하게 생각하시나요? (y/n): ")

    if answer2.lower() == 'y':
        # 감각형(내향, 감각)
        answer3 = input("Q3. 일정을 엄격하게 관리하는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ISTJ입니다!")
        else:
            print("당신의 성격 유형은 ISFP입니다!")
    else:
        # 직관형(내향, 직관)
        answer3 = input("Q3. 논리적인 문제 해결을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 INTP입니다!")
        else:
            print("당신의 성격 유형은 INFJ입니다!")
# Out:
# MBTI 간단 성격 유형 검사에 오신 걸 환영합니다!
# Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): y
# 외향형으로 분석 중...
# Q2. 주변 환경에 대해 자주 인지하고 있나요? (y/n): y
# Q3. 계획을 세우는 것을 좋아하시나요? (y/n): y
# 당신의 성격 유형은 ESTJ입니다!

# %%
print("MBTI 간단 성격 유형 검사에 오신 걸 환영합니다!")

# 첫 번째 질문: 외향/내향
answer1 = input("Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): ")
while answer1 != 'y' or 'n':
  print('y 또는 n으로 입력해주세요')
  answer1 = input("Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): ")
if answer1.lower() == 'y':
    # 외향형으로 진행
    print("외향형으로 분석 중...")
    answer2 = input("Q2. 주변 환경에 대해 자주 인지하고 있나요? (y/n): ")
    while answer2 != 'y' or 'n':
      print('y 또는 n으로 입력해주세요')
      answer2 = input("Q2. 주변 환경에 대해 자주 인지하고 있나요? (y/n): ")
    if answer2.lower() == 'y':
        # 감각형(외향, 감각)
        answer3 = input("Q3. 계획을 세우는 것을 좋아하시나요? (y/n): ")
        while answer3 != 'y' or 'n':
          print('y 또는 n으로 입력해주세요')
          answer3 = input("Q3. 계획을 세우는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ESTJ입니다!")
        else:
            print("당신의 성격 유형은 ESFP입니다!")
    else:
        # 직관형(외향, 직관)
        answer3 = input("Q3. 큰 그림을 보는 것을 좋아하시나요? (y/n): ")
        while answer3 != 'y' or 'n':
          print('y 또는 n으로 입력해주세요')
          answer3 = input("Q3. 큰 그림을 보는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ENFP입니다!")
        else:
            print("당신의 성격 유형은 ENTJ입니다!")

else:
    # 내향형으로 진행
    print("내향형으로 분석 중...")
    answer2 = input("Q2. 구체적인 정보나 사실을 중요하게 생각하시나요? (y/n): ")
    while answer2 != 'y' or 'n':
          print('y 또는 n으로 입력해주세요')
          answer2 = input("Q2. 구체적인 정보나 사실을 중요하게 생각하시나요? (y/n): ")

    if answer2.lower() == 'y':
        # 감각형(내향, 감각)
        answer3 = input("Q3. 일정을 엄격하게 관리하는 것을 좋아하시나요? (y/n): ")
        while answer3 != 'y' or 'n':
          print('y 또는 n으로 입력해주세요')
          answer3 = input("Q3. 일정을 엄격하게 관리하는 것을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 ISTJ입니다!")
        else:
            print("당신의 성격 유형은 ISFP입니다!")
    else:
        # 직관형(내향, 직관)
        answer3 = input("Q3. 논리적인 문제 해결을 좋아하시나요? (y/n): ")
        while answer3 != 'y' or 'n':
          print('y 또는 n으로 입력해주세요')
          answer3 = input("Q3. 논리적인 문제 해결을 좋아하시나요? (y/n): ")
        if answer3.lower() == 'y':
            print("당신의 성격 유형은 INTP입니다!")
        else:
            print("당신의 성격 유형은 INFJ입니다!")
# Out:
# MBTI 간단 성격 유형 검사에 오신 걸 환영합니다!
# Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): y
# y 또는 n으로 입력해주세요
# Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): n
# y 또는 n으로 입력해주세요
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-24f833fa5467> in <cell line: 5>()
#       5 while answer1 != 'y' or 'n':
#       6   print('y 또는 n으로 입력해주세요')
# ----> 7   answer1 = input("Q1. 새로운 사람들과 만나는 걸 좋아하시나요? (y/n): ")
#       8   continue;
#       9 if answer1.lower() == 'y':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # **5. 조건부표현식**
# 조건부 표현식은 파이썬에서 삼항연산자라고도 불립니다. 간단한 if-else 구문을 더 간결하게 표현할 수 있는 방법을 제공합니다.  조건부 표현식은 코드를 간결하게 만들어주지만, 너무 복잡한 조건이나 연산을 포함하면 코드의 가독성이 떨어질 수 있습니다. 따라서 적절한 상황에서만 사용하는 것이 좋습니다.
#
# ```
# 조건이 참인 경우 값 if 조건 else 조건이 거짓인 경우 값
# ```

# %%
# if ~ else로 작성
num = int(input('숫자를 입력하세요: '))
if num % 2 == 0:
  print('짝수입니다')
else:
  print('홀수입니다')
# Out:
# 숫자를 입력하세요: 99
# 홀수입니다

# %%
num = int(input('숫자를 입력하세요: '))
print('짝수입니다.') if num % 2 == 0 else print('홀수입니다.')
# Out:
# 숫자를 입력하세요: 0
# 짝수입니다.

# %%
age = int(input('나이를 입력하세요: '))

if age > 19:
  print('성인입니다')
elif age > 14:
  print('청소년입니다')
elif age > 6:
  print('어린이입니다')
elif age > 0:
  print('유아입니다')
else:
  print('입력을 확인해주세요')

print('입력한 나이:', age)
# Out:
# 나이를 입력하세요: 20
# 성인입니다
# 입력한 나이: 20

# %%
age = int(input('나이를 입력하세요: '))

print('성인입니다') if age > 19 else print('청소년입니다') if age > 14 else print('어린이입니다') if age > 6 else print('유아입니다') if age > 0 else print('입력을 확인해주세요')
# Out:
# 나이를 입력하세요: 99
# 성인입니다
