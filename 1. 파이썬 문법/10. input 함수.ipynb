# %% [markdown]
# # **1. input 함수**
# input() 함수는 사용자로부터 키보드 입력을 받는 데 사용되는 내장 함수입니다. 프로그램 실행 중에 사용자가 값을 입력하면, 입력한 값이 문자열로 반환되어 변수에 저장하거나 처리할 수 있습니다.

# %%
input()
# Out:
# 100
# '100'

# %%
name = input()
print(name)
# Out:
# 먹벅이
# 먹벅이

# %%
name = input("이름을 입력하세요: ")
print(f'{name}님 안녕하세요')
# Out:
# 이름을 입력하세요: 먹벅이
# 먹벅이님 안녕하세요

# %%
name, age, weight = '김사과', 20, 50.5
print(name)
print(age)
print(weight)
# Out:
# 김사과
# 20
# 50.5

# %%
info = '먹벅이 26 50.5'.split(' ')
print(info)
# Out:
# ['먹벅이', '26', '50.5']

# %%
name, age, weight = input('이름, 나이, 몸무게를 차례대로 입력하세요').split(' ')
print(name)
print(age)
print(weight)
# Out:
# 이름, 나이, 몸무게를 차례대로 입력하세요먹벅이 26 80
# 먹벅이
# 26
# 80

# %%
num1 = input('첫번째 숫자를 입력하세요')
num2 = input('두번째 숫자를 입력하세요')
print('결과: ', num1 + num2)
# Out:
# 첫번째 숫자를 입력하세요2
# 두번째 숫자를 입력하세요3
# 결과:  23

# %%
# int(): 문자열을 숫자(정수)타입으로 변환
num1 = input('첫번째 숫자를 입력하세요')
num2 = input('두번째 숫자를 입력하세요')
print('결과: ', int(num1) + int(num2))
# Out:
# 첫번째 숫자를 입력하세요2
# 두번째 숫자를 입력하세요3
# 결과:  5

# %%
num1 = input('첫번째 숫자를 입력하세요')
num2 = input('두번째 숫자를 입력하세요')
print('결과: ', int(num1 + num2))
# Out:
# 첫번째 숫자를 입력하세요2
# 두번째 숫자를 입력하세요3
# 결과:  23

# %%
num1 = int(input('첫번째 숫자를 입력하세요'))
num2 = int(input('두번째 숫자를 입력하세요'))
print('결과: ', num1 + num2)
# Out:
# 첫번째 숫자를 입력하세요2
# 두번째 숫자를 입력하세요3
# 결과:  5
